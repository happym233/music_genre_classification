# %%
import os

# %% [markdown]
# ## switch to the root dir

# %%
os.chdir('..')
os.listdir()
# Out:
# ['sbin',
#  'sys',
#  'root',
#  'home',
#  'boot',
#  'dev',
#  'var',
#  'media',
#  'lib',
#  'opt',
#  'mnt',
#  'usr',
#  'bin',
#  'srv',
#  'run',
#  'tmp',
#  'proc',
#  'etc',
#  'lib64',
#  'content',
#  '.dockerenv',
#  'datalab',
#  'tools',
#  'tensorflow-1.15.2',
#  'python-apt',
#  'lib32']

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/6321_project')
os.listdir()
# Out:
# ['processed_data',
#  'trainers',
#  'models',
#  'data_processor',
#  'data_loader',
#  'jupyter',
#  'loggers',
#  'saved_models',
#  'model']

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.MusicCNN2d import MusicCNN2d
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
X_train, y_train, X_val, y_val = load_numpy_arrays(['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy']
                  , path_prefix='processed_data/processed_waves/10-genres/')

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([1598, 501, 40])
# torch.Size([1598])

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([[-2.2515, -1.9039, -1.6231,  ..., -2.0267, -1.9376, -1.7817],
#         [-1.4637, -1.7655, -1.9270,  ..., -1.4429, -1.5084, -1.7305],
#         [-1.7726, -2.1026, -2.2693,  ..., -1.8113, -1.7369, -1.7406],
#         ...,
#         [-0.0146, -0.0134, -0.1776,  ..., -1.3860, -1.6582, -1.5008],
#         [ 0.0930,  0.1538, -0.0341,  ..., -1.1890, -1.5168, -1.6089],
#         [-0.1187, -0.2323, -0.3049,  ..., -1.4563, -1.3284, -1.3372]])
# tensor(2)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([200, 501, 40])
# torch.Size([200])

# %% [markdown]
# ## Load model
#
# 1. define model under the folder models
# 2. import and define the model

# %%
model = MusicCNN2d([8, 16, 64, 64], 3968, [600], 10, True)

# %%
n_feat = X_train.shape[2]
n_time = X_train.shape[1]

# %%
X_a = X_train[:10].reshape((-1, 1, n_time, n_feat))
print(X_a.shape)
pred = model(X_a)
print(pred.shape)
# Out:
# torch.Size([10, 1, 501, 40])
# torch.Size([10, 10])

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.001
batch_size = 500
weight_decay = 1e-5
num_epoch = 30
model_name = 'CNN2d_ResBlock'
saved_model_name = 'saved_models/saved_' + model_name + '_wave.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
X_train_2d = X_train.reshape((-1, 1, n_time, n_feat))
#print(X_train.shape)
X_val_2d = X_val.reshape((-1, 1, n_time, n_feat))
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train_2d, y_train, X_val_2d, y_val), 
                  loss, optimizer, batch_size = batch_size, num_epoch = num_epoch, device='cuda', saved_model_name=saved_model_name)
# Out:
# Epoch  0: loss on final training batch: 2.2260
# training accuracy: 32.42% validation accuracy: 28.00%
# Epoch  1: loss on final training batch: 1.5075
# training accuracy: 46.37% validation accuracy: 40.50%
# Epoch  2: loss on final training batch: 0.9878
# training accuracy: 54.69% validation accuracy: 47.50%
# Epoch  3: loss on final training batch: 0.7020
# training accuracy: 62.95% validation accuracy: 58.00%
# Epoch  4: loss on final training batch: 0.3848
# training accuracy: 69.90% validation accuracy: 61.00%
# Epoch  5: loss on final training batch: 0.2530
# training accuracy: 75.66% validation accuracy: 62.00%
# Epoch  6: loss on final training batch: 0.1253
# training accuracy: 81.41% validation accuracy: 66.50%
# Epoch  7: loss on final training batch: 0.0530
# training accuracy: 85.79% validation accuracy: 65.00%
# Epoch  8: loss on final training batch: 0.0345
# training accuracy: 92.55% validation accuracy: 64.50%
# Epoch  9: loss on final training batch: 0.0167
# training accuracy: 93.43% validation accuracy: 67.50%
# Epoch 10: loss on final training batch: 0.0114
# training accuracy: 97.87% validation accuracy: 70.00%
# Epoch 11: loss on final training batch: 0.0085
# training accuracy: 98.87% validation accuracy: 69.00%
# Epoch 12: loss on final training batch: 0.0068
# training accuracy: 98.87% validation accuracy: 73.00%
# Epoch 13: loss on final training batch: 0.0039
# training accuracy: 99.62% validation accuracy: 72.00%
# Epoch 14: loss on final training batch: 0.0078
# training accuracy: 99.37% validation accuracy: 69.50%
# Epoch 15: loss on final training batch: 0.0027
# training accuracy: 99.94% validation accuracy: 71.50%
# Epoch 16: loss on final training batch: 0.0021
# training accuracy: 99.81% validation accuracy: 71.50%
# Epoch 17: loss on final training batch: 0.0030
# training accuracy: 99.81% validation accuracy: 68.00%
# Epoch 18: loss on final training batch: 0.0013
# training accuracy: 99.94% validation accuracy: 69.50%
# Epoch 19: loss on final training batch: 0.0011
# training accuracy: 99.81% validation accuracy: 71.50%
# Epoch 20: loss on final training batch: 0.0016
# training accuracy: 99.94% validation accuracy: 70.50%
# Epoch 21: loss on final training batch: 0.0006
# training accuracy: 99.94% validation accuracy: 71.00%
# Epoch 22: loss on final training batch: 0.0004
# training accuracy: 99.94% validation accuracy: 70.00%
# Epoch 23: loss on final training batch: 0.0002
# training accuracy: 99.94% validation accuracy: 72.00%
# Epoch 24: loss on final training batch: 0.0002
# training accuracy: 99.94% validation accuracy: 74.00%
# Epoch 25: loss on final training batch: 0.0003
# training accuracy: 99.94% validation accuracy: 74.50%
# Epoch 26: loss on final training batch: 0.0002
# training accuracy: 99.94% validation accuracy: 75.50%
# Epoch 27: loss on final training batch: 0.0001
# training accuracy: 99.94% validation accuracy: 75.50%
# Epoch 28: loss on final training batch: 0.0001
# training accuracy: 99.94% validation accuracy: 74.00%
# Epoch 29: loss on final training batch: 0.0001
# training accuracy: 99.94% validation accuracy: 74.00%

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array[10:], validation_loss_array[10:]], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)
