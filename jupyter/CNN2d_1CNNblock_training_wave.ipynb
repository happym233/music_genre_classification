# %%
import os

# %% [markdown]
# ## switch to the root dir

# %%
os.chdir('..')
os.listdir()
# Out:
# ['media',
#  'home',
#  'srv',
#  'etc',
#  'usr',
#  'tmp',
#  'boot',
#  'lib64',
#  'mnt',
#  'dev',
#  'sys',
#  'run',
#  'root',
#  'bin',
#  'proc',
#  'var',
#  'sbin',
#  'lib',
#  'opt',
#  'content',
#  '.dockerenv',
#  'datalab',
#  'tools',
#  'tensorflow-1.15.2',
#  'lib32',
#  'python-apt']

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/6321_project')
os.listdir()
# Out:
# ['processed_data',
#  'trainers',
#  'models',
#  'data_processor',
#  'data_loader',
#  'jupyter',
#  'loggers',
#  'saved_models',
#  'model']

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.MusicCNN2d import MusicCNN2d_1layer
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
X_train, y_train, X_val, y_val = load_numpy_arrays(['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy']
                  , path_prefix='processed_data/processed_waves/10-genres/')

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([1598, 501, 40])
# torch.Size([1598])

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([[-2.2515, -1.9039, -1.6231,  ..., -2.0267, -1.9376, -1.7817],
#         [-1.4637, -1.7655, -1.9270,  ..., -1.4429, -1.5084, -1.7305],
#         [-1.7726, -2.1026, -2.2693,  ..., -1.8113, -1.7369, -1.7406],
#         ...,
#         [-0.0146, -0.0134, -0.1776,  ..., -1.3860, -1.6582, -1.5008],
#         [ 0.0930,  0.1538, -0.0341,  ..., -1.1890, -1.5168, -1.6089],
#         [-0.1187, -0.2323, -0.3049,  ..., -1.4563, -1.3284, -1.3372]])
# tensor(2)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([200, 501, 40])
# torch.Size([200])

# %% [markdown]
# ## Load model
#
# 1. define model under the folder models
# 2. import and define the model

# %%
model = MusicCNN2d_1layer(10, 16, 20000)

# %%
n_feat = X_train.shape[2]
n_time = X_train.shape[1]

# %%
X_a = X_train[:10].reshape((-1, 1, n_time, n_feat))
print(X_a.shape)
pred = model(X_a)
print(pred.shape)
# Out:
# torch.Size([10, 1, 501, 40])
# torch.Size([10, 10])

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.001
batch_size = 300
num_epoch = 50
model_name = 'CNN2d_1layer'
saved_model_name = 'saved_models/saved_' + model_name + '_wave.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
X_train_2d = X_train.reshape((-1, 1, n_time, n_feat))
#print(X_train.shape)
X_val_2d = X_val.reshape((-1, 1, n_time, n_feat))
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train_2d, y_train, X_val_2d, y_val), 
                  loss, optimizer, batch_size = batch_size, num_epoch = num_epoch, device='cuda', saved_model_name=saved_model_name)
# Out:
# Epoch  0: loss on final training batch: 10.6800
# training accuracy: 12.95% validation accuracy: 12.00%
# Epoch  1: loss on final training batch: 2.5056
# training accuracy: 10.76% validation accuracy: 8.50%
# Epoch  2: loss on final training batch: 2.1888
# training accuracy: 22.09% validation accuracy: 21.50%
# Epoch  3: loss on final training batch: 1.7966
# training accuracy: 26.41% validation accuracy: 26.50%
# Epoch  4: loss on final training batch: 1.6761
# training accuracy: 33.10% validation accuracy: 37.00%
# Epoch  5: loss on final training batch: 1.6014
# training accuracy: 37.98% validation accuracy: 33.00%
# Epoch  6: loss on final training batch: 1.4606
# training accuracy: 45.24% validation accuracy: 42.50%
# Epoch  7: loss on final training batch: 1.3185
# training accuracy: 48.37% validation accuracy: 41.50%
# Epoch  8: loss on final training batch: 1.2335
# training accuracy: 54.01% validation accuracy: 44.50%
# Epoch  9: loss on final training batch: 1.0892
# training accuracy: 58.45% validation accuracy: 45.50%
# Epoch 10: loss on final training batch: 0.9478
# training accuracy: 63.14% validation accuracy: 47.50%
# Epoch 11: loss on final training batch: 0.8101
# training accuracy: 66.21% validation accuracy: 47.50%
# Epoch 12: loss on final training batch: 0.6898
# training accuracy: 69.96% validation accuracy: 48.50%
# Epoch 13: loss on final training batch: 0.5634
# training accuracy: 72.90% validation accuracy: 50.00%
# Epoch 14: loss on final training batch: 0.4531
# training accuracy: 76.91% validation accuracy: 50.50%
# Epoch 15: loss on final training batch: 0.3564
# training accuracy: 80.04% validation accuracy: 49.50%
# Epoch 16: loss on final training batch: 0.2712
# training accuracy: 82.35% validation accuracy: 52.50%
# Epoch 17: loss on final training batch: 0.2163
# training accuracy: 83.67% validation accuracy: 52.50%
# Epoch 18: loss on final training batch: 0.1712
# training accuracy: 85.04% validation accuracy: 51.00%
# Epoch 19: loss on final training batch: 0.1313
# training accuracy: 87.80% validation accuracy: 49.50%
# Epoch 20: loss on final training batch: 0.1216
# training accuracy: 89.74% validation accuracy: 51.50%
# Epoch 21: loss on final training batch: 0.1605
# training accuracy: 90.05% validation accuracy: 53.00%
# Epoch 22: loss on final training batch: 0.1713
# training accuracy: 90.74% validation accuracy: 51.50%
# Epoch 23: loss on final training batch: 0.0628
# training accuracy: 94.81% validation accuracy: 54.00%
# Epoch 24: loss on final training batch: 0.0528
# training accuracy: 96.06% validation accuracy: 53.00%
# Epoch 25: loss on final training batch: 0.0514
# training accuracy: 94.99% validation accuracy: 54.00%
# Epoch 26: loss on final training batch: 0.0452
# training accuracy: 94.12% validation accuracy: 53.00%
# Epoch 27: loss on final training batch: 0.0437
# training accuracy: 94.31% validation accuracy: 51.00%
# Epoch 28: loss on final training batch: 0.0337
# training accuracy: 92.30% validation accuracy: 53.50%
# Epoch 29: loss on final training batch: 0.0599
# training accuracy: 89.42% validation accuracy: 49.50%
# Epoch 30: loss on final training batch: 0.1309
# training accuracy: 86.30% validation accuracy: 46.00%
# Epoch 31: loss on final training batch: 0.0742
# training accuracy: 87.67% validation accuracy: 46.50%
# Epoch 32: loss on final training batch: 0.1176
# training accuracy: 89.11% validation accuracy: 52.00%
# Epoch 33: loss on final training batch: 0.0578
# training accuracy: 95.99% validation accuracy: 50.00%
# Epoch 34: loss on final training batch: 0.0465
# training accuracy: 97.68% validation accuracy: 53.00%
# Epoch 35: loss on final training batch: 0.0249
# training accuracy: 98.87% validation accuracy: 51.50%
# Epoch 36: loss on final training batch: 0.0132
# training accuracy: 99.56% validation accuracy: 56.50%
# Epoch 37: loss on final training batch: 0.0089
# training accuracy: 99.81% validation accuracy: 56.00%
# Epoch 38: loss on final training batch: 0.0063
# training accuracy: 99.87% validation accuracy: 56.00%
# Epoch 39: loss on final training batch: 0.0051
# training accuracy: 99.94% validation accuracy: 55.50%
# Epoch 40: loss on final training batch: 0.0044
# training accuracy: 99.94% validation accuracy: 59.00%
# Epoch 41: loss on final training batch: 0.0042
# training accuracy: 99.94% validation accuracy: 54.50%
# Epoch 42: loss on final training batch: 0.0036
# training accuracy: 99.94% validation accuracy: 58.00%
# Epoch 43: loss on final training batch: 0.0035
# training accuracy: 99.94% validation accuracy: 54.00%
# Epoch 44: loss on final training batch: 0.0031
# training accuracy: 99.94% validation accuracy: 55.50%
# Epoch 45: loss on final training batch: 0.0031
# training accuracy: 99.94% validation accuracy: 55.00%
# Epoch 46: loss on final training batch: 0.0027
# training accuracy: 99.94% validation accuracy: 57.50%
# Epoch 47: loss on final training batch: 0.0026
# training accuracy: 99.94% validation accuracy: 56.00%
# Epoch 48: loss on final training batch: 0.0025
# training accuracy: 99.94% validation accuracy: 56.00%
# Epoch 49: loss on final training batch: 0.0023
# training accuracy: 99.94% validation accuracy: 56.00%

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array[10:], validation_loss_array[10:]], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)
