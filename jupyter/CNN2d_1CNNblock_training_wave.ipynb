# %%
import os

# %% [markdown]
# ## switch to the root dir

# %%
os.chdir('..')
os.listdir()
# Out:
# ['sbin',
#  'sys',
#  'root',
#  'home',
#  'boot',
#  'dev',
#  'var',
#  'media',
#  'lib',
#  'opt',
#  'mnt',
#  'usr',
#  'bin',
#  'srv',
#  'run',
#  'tmp',
#  'proc',
#  'etc',
#  'lib64',
#  'content',
#  '.dockerenv',
#  'datalab',
#  'tools',
#  'tensorflow-1.15.2',
#  'python-apt',
#  'lib32']

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/6321_project')
os.listdir()
# Out:
# ['processed_data',
#  'trainers',
#  'models',
#  'data_processor',
#  'data_loader',
#  'jupyter',
#  'loggers',
#  'saved_models',
#  'model']

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.MusicCNN2d import MusicCNN2d_1CNNBlock
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
X_train, y_train, X_val, y_val = load_numpy_arrays(['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy']
                  , path_prefix='processed_data/processed_waves/10-genres/')

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([1598, 501, 40])
# torch.Size([1598])

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([[-2.2515, -1.9039, -1.6231,  ..., -2.0267, -1.9376, -1.7817],
#         [-1.4637, -1.7655, -1.9270,  ..., -1.4429, -1.5084, -1.7305],
#         [-1.7726, -2.1026, -2.2693,  ..., -1.8113, -1.7369, -1.7406],
#         ...,
#         [-0.0146, -0.0134, -0.1776,  ..., -1.3860, -1.6582, -1.5008],
#         [ 0.0930,  0.1538, -0.0341,  ..., -1.1890, -1.5168, -1.6089],
#         [-0.1187, -0.2323, -0.3049,  ..., -1.4563, -1.3284, -1.3372]])
# tensor(2)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([200, 501, 40])
# torch.Size([200])

# %% [markdown]
# ## Load model
#
# 1. define model under the folder models
# 2. import and define the model

# %%
model = MusicCNN2d_1CNNBlock(10, 16, 20000)

# %%
n_feat = X_train.shape[2]
n_time = X_train.shape[1]

# %%
X_a = X_train[:10].reshape((-1, 1, n_time, n_feat))
print(X_a.shape)
pred = model(X_a)
print(pred.shape)
# Out:
# torch.Size([10, 1, 501, 40])
# torch.Size([10, 10])

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.001
batch_size = 300
num_epoch = 50
model_name = 'CNN2d_1CNNBlock'
saved_model_name = 'saved_models/saved_' + model_name + '_wave.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
X_train_2d = X_train.reshape((-1, 1, n_time, n_feat))
#print(X_train.shape)
X_val_2d = X_val.reshape((-1, 1, n_time, n_feat))
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train_2d, y_train, X_val_2d, y_val), 
                  loss, optimizer, batch_size = batch_size, num_epoch = num_epoch, device='cuda', saved_model_name=saved_model_name)
# Out:
# Epoch  0: loss on final training batch: 19.4264
# training accuracy: 18.96% validation accuracy: 16.00%
# Epoch  1: loss on final training batch: 2.2592
# training accuracy: 29.91% validation accuracy: 24.50%
# Epoch  2: loss on final training batch: 1.9483
# training accuracy: 34.36% validation accuracy: 32.00%
# Epoch  3: loss on final training batch: 1.4917
# training accuracy: 40.55% validation accuracy: 38.00%
# Epoch  4: loss on final training batch: 1.3064
# training accuracy: 47.81% validation accuracy: 38.50%
# Epoch  5: loss on final training batch: 1.0266
# training accuracy: 60.26% validation accuracy: 44.00%
# Epoch  6: loss on final training batch: 0.7357
# training accuracy: 63.02% validation accuracy: 46.00%
# Epoch  7: loss on final training batch: 0.5784
# training accuracy: 68.21% validation accuracy: 46.50%
# Epoch  8: loss on final training batch: 0.4128
# training accuracy: 72.03% validation accuracy: 46.50%
# Epoch  9: loss on final training batch: 0.2442
# training accuracy: 79.85% validation accuracy: 53.50%
# Epoch 10: loss on final training batch: 0.1910
# training accuracy: 84.29% validation accuracy: 58.00%
# Epoch 11: loss on final training batch: 0.1531
# training accuracy: 89.86% validation accuracy: 53.50%
# Epoch 12: loss on final training batch: 0.1602
# training accuracy: 91.61% validation accuracy: 50.50%
# Epoch 13: loss on final training batch: 0.0711
# training accuracy: 95.37% validation accuracy: 59.00%
# Epoch 14: loss on final training batch: 0.0380
# training accuracy: 97.75% validation accuracy: 56.00%
# Epoch 15: loss on final training batch: 0.0221
# training accuracy: 99.69% validation accuracy: 60.00%
# Epoch 16: loss on final training batch: 0.0112
# training accuracy: 99.94% validation accuracy: 60.00%
# Epoch 17: loss on final training batch: 0.0076
# training accuracy: 99.94% validation accuracy: 60.50%
# Epoch 18: loss on final training batch: 0.0051
# training accuracy: 99.94% validation accuracy: 63.50%
# Epoch 19: loss on final training batch: 0.0041
# training accuracy: 99.94% validation accuracy: 61.50%
# Epoch 20: loss on final training batch: 0.0034
# training accuracy: 99.94% validation accuracy: 60.00%
# Epoch 21: loss on final training batch: 0.0026
# training accuracy: 99.94% validation accuracy: 60.50%
# Epoch 22: loss on final training batch: 0.0021
# training accuracy: 99.94% validation accuracy: 63.00%
# Epoch 23: loss on final training batch: 0.0018
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 24: loss on final training batch: 0.0016
# training accuracy: 99.94% validation accuracy: 60.50%
# Epoch 25: loss on final training batch: 0.0014
# training accuracy: 99.94% validation accuracy: 60.50%
# Epoch 26: loss on final training batch: 0.0012
# training accuracy: 99.94% validation accuracy: 61.50%
# Epoch 27: loss on final training batch: 0.0011
# training accuracy: 99.94% validation accuracy: 61.50%
# Epoch 28: loss on final training batch: 0.0010
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 29: loss on final training batch: 0.0009
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 30: loss on final training batch: 0.0009
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 31: loss on final training batch: 0.0008
# training accuracy: 99.94% validation accuracy: 63.50%
# Epoch 32: loss on final training batch: 0.0007
# training accuracy: 99.94% validation accuracy: 63.50%
# Epoch 33: loss on final training batch: 0.0007
# training accuracy: 99.94% validation accuracy: 63.00%
# Epoch 34: loss on final training batch: 0.0007
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 35: loss on final training batch: 0.0006
# training accuracy: 99.94% validation accuracy: 63.00%
# Epoch 36: loss on final training batch: 0.0006
# training accuracy: 99.94% validation accuracy: 63.00%
# Epoch 37: loss on final training batch: 0.0006
# training accuracy: 99.94% validation accuracy: 63.00%
# Epoch 38: loss on final training batch: 0.0005
# training accuracy: 99.94% validation accuracy: 63.00%
# Epoch 39: loss on final training batch: 0.0005
# training accuracy: 99.94% validation accuracy: 63.00%
# Epoch 40: loss on final training batch: 0.0005
# training accuracy: 99.94% validation accuracy: 63.00%
# Epoch 41: loss on final training batch: 0.0005
# training accuracy: 99.94% validation accuracy: 63.00%
# Epoch 42: loss on final training batch: 0.0004
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 43: loss on final training batch: 0.0004
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 44: loss on final training batch: 0.0004
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 45: loss on final training batch: 0.0004
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 46: loss on final training batch: 0.0004
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 47: loss on final training batch: 0.0003
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 48: loss on final training batch: 0.0003
# training accuracy: 99.94% validation accuracy: 62.50%
# Epoch 49: loss on final training batch: 0.0003
# training accuracy: 99.94% validation accuracy: 62.00%

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array[10:], validation_loss_array[10:]], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)
