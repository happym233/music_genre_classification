# %%
import os

# %%
os.chdir('..')

# %%
os.listdir()
# Out:
# ['.git',
#  '.idea',
#  'data_loader',
#  'data_processor',
#  'jupyter',
#  'loggers',
#  'main.py',
#  'models',
#  'original_data',
#  'processed_data',
#  'README.md',
#  'saved_models',
#  'trainers']

# %%
from data_processor.data_handler import load_numpy_arrays, numpy_to_tensor
from models.Linear import LogisticRegression
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch

# %%
data_train, data_val = load_numpy_arrays(['data_train.npy', 'data_val.npy'], 
                                            path_prefix='processed_data/processed_features/4-genres/')

# %%
X_train, y_train = data_train[:, :-4], data_train[:, -4:]
X_val, y_val = data_val[:, :-4], data_val[:, -4:]

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([400, 57])
# torch.Size([400, 4])

# %%
model = LogisticRegression(57, 4)

# %%
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, [X_train, y_train, X_val, y_val])
# Out:
# Epoch  0: loss on final training batch: 1.1869
# training accuracy: 63.71% validation accuracy: 68.75%
# Epoch  1: loss on final training batch: 1.1150
# training accuracy: 69.13% validation accuracy: 71.50%
# Epoch  2: loss on final training batch: 1.0890
# training accuracy: 72.70% validation accuracy: 73.75%
# Epoch  3: loss on final training batch: 1.0713
# training accuracy: 75.08% validation accuracy: 76.50%
# Epoch  4: loss on final training batch: 1.0576
# training accuracy: 77.46% validation accuracy: 77.75%
# Epoch  5: loss on final training batch: 1.0458
# training accuracy: 78.43% validation accuracy: 79.00%
# Epoch  6: loss on final training batch: 1.0350
# training accuracy: 79.52% validation accuracy: 80.25%
# Epoch  7: loss on final training batch: 1.0250
# training accuracy: 80.81% validation accuracy: 81.00%
# Epoch  8: loss on final training batch: 1.0158
# training accuracy: 81.81% validation accuracy: 82.50%
# Epoch  9: loss on final training batch: 1.0075
# training accuracy: 82.65% validation accuracy: 83.00%
# Epoch 10: loss on final training batch: 1.0001
# training accuracy: 83.59% validation accuracy: 84.00%
# Epoch 11: loss on final training batch: 0.9936
# training accuracy: 84.19% validation accuracy: 84.75%
# Epoch 12: loss on final training batch: 0.9881
# training accuracy: 84.85% validation accuracy: 85.50%
# Epoch 13: loss on final training batch: 0.9834
# training accuracy: 85.25% validation accuracy: 85.00%
# Epoch 14: loss on final training batch: 0.9793
# training accuracy: 85.57% validation accuracy: 85.50%
# Epoch 15: loss on final training batch: 0.9758
# training accuracy: 85.85% validation accuracy: 85.50%
# Epoch 16: loss on final training batch: 0.9728
# training accuracy: 85.94% validation accuracy: 85.75%
# Epoch 17: loss on final training batch: 0.9701
# training accuracy: 86.22% validation accuracy: 86.00%
# Epoch 18: loss on final training batch: 0.9677
# training accuracy: 86.29% validation accuracy: 86.25%
# Epoch 19: loss on final training batch: 0.9655
# training accuracy: 86.41% validation accuracy: 86.75%
# Epoch 20: loss on final training batch: 0.9636
# training accuracy: 86.47% validation accuracy: 86.75%
# Epoch 21: loss on final training batch: 0.9618
# training accuracy: 86.69% validation accuracy: 87.25%
# Epoch 22: loss on final training batch: 0.9601
# training accuracy: 86.82% validation accuracy: 87.75%
# Epoch 23: loss on final training batch: 0.9586
# training accuracy: 87.04% validation accuracy: 88.00%
# Epoch 24: loss on final training batch: 0.9572
# training accuracy: 87.04% validation accuracy: 88.00%
# Epoch 25: loss on final training batch: 0.9559
# training accuracy: 87.16% validation accuracy: 88.25%
# Epoch 26: loss on final training batch: 0.9547
# training accuracy: 87.23% validation accuracy: 88.25%
# Epoch 27: loss on final training batch: 0.9535
# training accuracy: 87.26% validation accuracy: 88.25%
# Epoch 28: loss on final training batch: 0.9524
# training accuracy: 87.41% validation accuracy: 88.25%
# Epoch 29: loss on final training batch: 0.9513
# training accuracy: 87.63% validation accuracy: 88.25%
# Epoch 30: loss on final training batch: 0.9503
# training accuracy: 87.70% validation accuracy: 88.25%
# Epoch 31: loss on final training batch: 0.9493
# training accuracy: 87.76% validation accuracy: 88.25%
# Epoch 32: loss on final training batch: 0.9484
# training accuracy: 87.79% validation accuracy: 88.25%
# Epoch 33: loss on final training batch: 0.9474
# training accuracy: 87.85% validation accuracy: 88.25%
# Epoch 34: loss on final training batch: 0.9466
# training accuracy: 87.95% validation accuracy: 88.25%
# Epoch 35: loss on final training batch: 0.9457
# training accuracy: 88.07% validation accuracy: 88.25%
# Epoch 36: loss on final training batch: 0.9449
# training accuracy: 88.29% validation accuracy: 88.25%
# Epoch 37: loss on final training batch: 0.9440
# training accuracy: 88.42% validation accuracy: 88.25%
# Epoch 38: loss on final training batch: 0.9432
# training accuracy: 88.45% validation accuracy: 88.25%
# Epoch 39: loss on final training batch: 0.9425
# training accuracy: 88.45% validation accuracy: 88.25%

# %%
plot_numerical_arrays([training_loss_array, validation_loss_array], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for logistic regression')

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for logistic regression')

# %%
torch.save(model.state_dict(), 'saved_models/saved_logistic_regression.pt')
