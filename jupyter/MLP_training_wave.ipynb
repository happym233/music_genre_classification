# %%
import os

# %% [markdown]
# ## switch to the root dir

# %%
os.chdir('..')
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.idea',
#  'data_loader',
#  'data_processor',
#  'jupyter',
#  'loggers',
#  'main.py',
#  'model',
#  'models',
#  'original_data',
#  'processed_data',
#  'README.md',
#  'requirements.txt',
#  'saved_models',
#  'trainers']

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.MLP import MLP
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
X_train, y_train, X_val, y_val = load_numpy_arrays(['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy']
                  , path_prefix='processed_data/processed_waves/10-genres/')

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([1598, 501, 40])
# torch.Size([1598])

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([200, 501, 40])
# torch.Size([200])

# %%
# example on 1_D neural network
X_train = X_train.reshape((-1, 20040))
X_val = X_val.reshape((-1, 20040))

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([-2.2515, -1.9039, -1.6231,  ..., -1.4563, -1.3284, -1.3372])
# tensor(2)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([200, 20040])
# torch.Size([200])

# %% [markdown]
# ## Load model

# %%
model = MLP(20040, 10, [1000], batch_norm=True)

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.01
batch_size = 200
num_epoch = 20
model_name = 'MLP'
saved_model_name = 'saved_models/saved_' + model_name + '_wave.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train, y_train, X_val, y_val), 
                                                                                                                            loss, optimizer, batch_size=batch_size, num_epoch=num_epoch, saved_model_name=saved_model_name, device='cuda')
# Out:
# Epoch  0: loss on final training batch: 3.3302
# training accuracy: 29.79% validation accuracy: 26.00%
# Epoch  1: loss on final training batch: 2.1949
# training accuracy: 38.99% validation accuracy: 31.00%
# Epoch  2: loss on final training batch: 1.5852
# training accuracy: 51.31% validation accuracy: 41.50%
# Epoch  3: loss on final training batch: 1.4632
# training accuracy: 57.13% validation accuracy: 43.50%
# Epoch  4: loss on final training batch: 1.3152
# training accuracy: 62.20% validation accuracy: 43.50%
# Epoch  5: loss on final training batch: 1.1684
# training accuracy: 69.34% validation accuracy: 50.50%
# Epoch  6: loss on final training batch: 0.8871
# training accuracy: 78.41% validation accuracy: 48.50%
# Epoch  7: loss on final training batch: 0.6236
# training accuracy: 86.48% validation accuracy: 48.00%
# Epoch  8: loss on final training batch: 0.3973
# training accuracy: 92.55% validation accuracy: 50.50%
# Epoch  9: loss on final training batch: 0.2961
# training accuracy: 95.24% validation accuracy: 51.50%
# Epoch 10: loss on final training batch: 0.2931
# training accuracy: 94.68% validation accuracy: 46.00%
# Epoch 11: loss on final training batch: 0.1559
# training accuracy: 96.75% validation accuracy: 51.50%
# Epoch 12: loss on final training batch: 0.2343
# training accuracy: 93.49% validation accuracy: 50.00%
# Epoch 13: loss on final training batch: 0.1516
# training accuracy: 96.56% validation accuracy: 48.50%
# Epoch 14: loss on final training batch: 0.0782
# training accuracy: 98.62% validation accuracy: 47.00%
# Epoch 15: loss on final training batch: 0.0938
# training accuracy: 99.00% validation accuracy: 49.00%
# Epoch 16: loss on final training batch: 0.1662
# training accuracy: 96.75% validation accuracy: 51.00%
# Epoch 17: loss on final training batch: 0.1356
# training accuracy: 97.00% validation accuracy: 49.50%
# Epoch 18: loss on final training batch: 0.0735
# training accuracy: 99.50% validation accuracy: 53.00%
# Epoch 19: loss on final training batch: 0.0955
# training accuracy: 97.75% validation accuracy: 46.00%

# %%
print(loss(model(X_val), y_val))
# Out:
# tensor(2.0891, grad_fn=<NllLossBackward0>)

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array[3:], validation_loss_array[3:]], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array[3:], validation_accuracy_array[3:]], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)
