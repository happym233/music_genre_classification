# %%
import os

# %% [markdown]
# ## switch to the root dir

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/6321_project')
os.listdir()
# Out:
# ['processed_data',
#  'trainers',
#  'models',
#  'data_processor',
#  'data_loader',
#  'jupyter',
#  'loggers',
#  'saved_models',
#  'model']

# %%
#os.chdir('..')
#os.listdir()

# %%
from data_processor.utils import load_numpy_arrays, numpy_to_tensor
from models.MusicLSTM import MusicLSTM
import trainers.SGD_trainer
from loggers.statistics_loggers import plot_numerical_arrays
import torch
from torch import nn

# %% [markdown]
# ## Load preprocessed data

# %%
X_train, y_train, X_val, y_val = load_numpy_arrays(['data_train_X.npy','data_train_y.npy', 'data_val_X.npy','data_val_y.npy']
                  , path_prefix='processed_data/processed_waves/10-genres/')

# %%
X_train, y_train, X_val, y_val = numpy_to_tensor([X_train, y_train, X_val, y_val])

# %%
y_train = y_train.type(torch.int64)
y_val = y_val.type(torch.int64)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([1598, 501, 40])
# torch.Size([1598])

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tensor([[-2.2515, -1.9039, -1.6231,  ..., -2.0267, -1.9376, -1.7817],
#         [-1.4637, -1.7655, -1.9270,  ..., -1.4429, -1.5084, -1.7305],
#         [-1.7726, -2.1026, -2.2693,  ..., -1.8113, -1.7369, -1.7406],
#         ...,
#         [-0.0146, -0.0134, -0.1776,  ..., -1.3860, -1.6582, -1.5008],
#         [ 0.0930,  0.1538, -0.0341,  ..., -1.1890, -1.5168, -1.6089],
#         [-0.1187, -0.2323, -0.3049,  ..., -1.4563, -1.3284, -1.3372]])
# tensor(2)

# %%
print(X_val.shape)
print(y_val.shape)
# Out:
# torch.Size([200, 501, 40])
# torch.Size([200])

# %% [markdown]
# ## Load model
#
# 1. define model under the folder models
# 2. import and define the model

# %%
model = MusicLSTM(input_size=40,
        hidden_size=40,
        output_size=10,
        num_layers=8,
        dropout=0.15,
        bidirectional=True
    )

# %%
n_feat = X_train.shape[2]
n_time = X_train.shape[1]

# %%
#X_train = X_train[:, range(0, n_time + 1, 4), :]
#X_val = X_val[:, range(0, n_time + 1, 4), :]

# %%
X_a = X_train[:10]
pred = model(X_a)

# %% [markdown]
# ## Define loss and optimizer

# %%
lr = 0.001
batch_size = 200
num_epoch = 200
model_name = 'LSTM_bidirectional'
saved_model_name = 'saved_models/saved_' + model_name + '_wave.pt'

# %%
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Train
#
# use trainers.SGD_trainer.train or define a trainer
#
# parameters of SGD_trainer.train
# - model
# - train_array: a tuple (X_train, y_train, X_val, y_val)
# - loss
# - optimizer
# - batch_size
# - num_epoch
# - device

# %%
training_loss_array, training_accuracy_array, validation_loss_array, validation_accuracy_array = trainers.SGD_trainer.train(model, (X_train, y_train, X_val, y_val), loss, optimizer, batch_size=batch_size, num_epoch=num_epoch, device='cuda', saved_model_name=saved_model_name)
# Out:
# Epoch  0: loss on final training batch: 2.3017
# training accuracy: 10.39% validation accuracy: 8.50%
# Epoch  1: loss on final training batch: 2.2485
# training accuracy: 18.09% validation accuracy: 17.50%
# Epoch  2: loss on final training batch: 2.1060
# training accuracy: 20.65% validation accuracy: 21.50%
# Epoch  3: loss on final training batch: 2.0000
# training accuracy: 20.65% validation accuracy: 23.00%
# Epoch 71: loss on final training batch: 0.9133
# training accuracy: 63.70% validation accuracy: 49.50%
# Epoch 72: loss on final training batch: 0.9548
# training accuracy: 65.02% validation accuracy: 53.00%
# Epoch 73: loss on final training batch: 0.8644
# training accuracy: 67.21% validation accuracy: 51.50%
# Epoch 74: loss on final training batch: 0.9665
# training accuracy: 66.40% validation accuracy: 52.00%
# Epoch 75: loss on final training batch: 0.9253
# training accuracy: 66.40% validation accuracy: 50.00%
# Epoch 76: loss on final training batch: 0.9509
# training accuracy: 66.33% validation accuracy: 50.50%
# Epoch 77: loss on final training batch: 0.8706
# training accuracy: 68.46% validation accuracy: 56.00%
# Epoch 78: loss on final training batch: 0.8974
# training accuracy: 66.40% validation accuracy: 51.50%
# Epoch 79: loss on final training batch: 0.9251
# training accuracy: 66.96% validation accuracy: 50.00%
# Epoch 80: loss on final training batch: 0.9205
# training accuracy: 65.77% validation accuracy: 49.50%
# Epoch 81: loss on final training batch: 0.9134
# training accuracy: 68.52% validation accuracy: 50.00%
# Epoch 82: loss on final training batch: 0.8572
# training accuracy: 68.96% validation accuracy: 47.00%
# Epoch 83: loss on final training batch: 0.8420
# training accuracy: 68.90% validation accuracy: 49.00%
# Epoch 84: loss on final training batch: 0.8838
# training accuracy: 70.09% validation accuracy: 52.50%
# Epoch 85: loss on final training batch: 0.9065
# training accuracy: 70.40% validation accuracy: 52.00%
# Epoch 86: loss on final training batch: 0.8318
# training accuracy: 72.72% validation accuracy: 52.00%
# Epoch 87: loss on final training batch: 0.8095
# training accuracy: 70.84% validation accuracy: 55.50%
# Epoch 88: loss on final training batch: 0.9826
# training accuracy: 65.83% validation accuracy: 52.00%
# Epoch 89: loss on final training batch: 0.9349
# training accuracy: 67.46% validation accuracy: 52.00%
# Epoch 90: loss on final training batch: 0.7839
# training accuracy: 71.53% validation accuracy: 52.50%
# Epoch 91: loss on final training batch: 0.7483
# training accuracy: 73.15% validation accuracy: 54.50%
# Epoch 92: loss on final training batch: 0.8202
# training accuracy: 72.40% validation accuracy: 54.00%
# Epoch 93: loss on final training batch: 0.8631
# training accuracy: 69.84% validation accuracy: 52.50%
# Epoch 94: loss on final training batch: 0.8879
# training accuracy: 71.84% validation accuracy: 54.50%
# Epoch 95: loss on final training batch: 0.8288
# training accuracy: 73.34% validation accuracy: 54.00%
# Epoch 96: loss on final training batch: 0.6993
# training accuracy: 74.97% validation accuracy: 54.50%
# Epoch 97: loss on final training batch: 0.6967
# training accuracy: 76.16% validation accuracy: 56.00%
# Epoch 98: loss on final training batch: 0.7797
# training accuracy: 74.16% validation accuracy: 51.00%
# Epoch 99: loss on final training batch: 0.9478
# training accuracy: 66.58% validation accuracy: 54.50%
# Epoch 100: loss on final training batch: 0.9323
# training accuracy: 70.34% validation accuracy: 55.00%
# Epoch 101: loss on final training batch: 0.9237
# training accuracy: 71.59% validation accuracy: 56.00%
# Epoch 102: loss on final training batch: 0.8028
# training accuracy: 72.59% validation accuracy: 58.00%
# Epoch 103: loss on final training batch: 0.8064
# training accuracy: 72.84% validation accuracy: 54.50%
# Epoch 104: loss on final training batch: 0.7699
# training accuracy: 75.03% validation accuracy: 52.50%
# Epoch 105: loss on final training batch: 0.6841
# training accuracy: 74.97% validation accuracy: 56.00%
# Epoch 106: loss on final training batch: 0.6164
# training accuracy: 76.72% validation accuracy: 60.00%
# Epoch 107: loss on final training batch: 0.6617
# training accuracy: 77.03% validation accuracy: 55.00%
# Epoch 108: loss on final training batch: 0.6825
# training accuracy: 75.84% validation accuracy: 54.50%
# Epoch 109: loss on final training batch: 0.6105
# training accuracy: 80.04% validation accuracy: 57.00%
# Epoch 110: loss on final training batch: 0.6186
# training accuracy: 77.16% validation accuracy: 54.50%
# Epoch 111: loss on final training batch: 0.6310
# training accuracy: 78.66% validation accuracy: 57.50%
# Epoch 112: loss on final training batch: 0.7068
# training accuracy: 75.66% validation accuracy: 53.50%
# Epoch 113: loss on final training batch: 0.6870
# training accuracy: 76.35% validation accuracy: 58.00%
# Epoch 114: loss on final training batch: 0.5873
# training accuracy: 79.16% validation accuracy: 54.50%
# Epoch 115: loss on final training batch: 0.6513
# training accuracy: 80.60% validation accuracy: 57.50%
# Epoch 116: loss on final training batch: 0.5792
# training accuracy: 81.35% validation accuracy: 56.50%
# Epoch 117: loss on final training batch: 0.4793
# training accuracy: 82.98% validation accuracy: 62.50%
# Epoch 118: loss on final training batch: 0.5400
# training accuracy: 80.91% validation accuracy: 57.50%
# Epoch 119: loss on final training batch: 0.5361
# training accuracy: 81.98% validation accuracy: 56.00%
# Epoch 120: loss on final training batch: 0.5426
# training accuracy: 81.48% validation accuracy: 57.50%
# Epoch 121: loss on final training batch: 0.6047
# training accuracy: 81.60% validation accuracy: 53.50%
# Epoch 122: loss on final training batch: 0.7115
# training accuracy: 76.60% validation accuracy: 53.50%
# Epoch 123: loss on final training batch: 0.7398
# training accuracy: 76.47% validation accuracy: 58.50%
# Epoch 124: loss on final training batch: 0.6754
# training accuracy: 76.72% validation accuracy: 53.50%
# Epoch 125: loss on final training batch: 0.6854
# training accuracy: 78.54% validation accuracy: 56.00%
# Epoch 126: loss on final training batch: 0.5816
# training accuracy: 80.23% validation accuracy: 56.00%
# Epoch 127: loss on final training batch: 0.5496
# training accuracy: 82.73% validation accuracy: 59.50%
# Epoch 128: loss on final training batch: 0.4923
# training accuracy: 83.60% validation accuracy: 57.50%
# Epoch 129: loss on final training batch: 0.5164
# training accuracy: 81.35% validation accuracy: 56.50%
# Epoch 130: loss on final training batch: 0.7129
# training accuracy: 78.97% validation accuracy: 54.50%
# Epoch 131: loss on final training batch: 1.5049
# training accuracy: 52.63% validation accuracy: 43.50%
# Epoch 132: loss on final training batch: 1.5632
# training accuracy: 50.31% validation accuracy: 48.50%
# Epoch 133: loss on final training batch: 1.3120
# training accuracy: 51.75% validation accuracy: 44.00%
# Epoch 134: loss on final training batch: 1.1422
# training accuracy: 56.88% validation accuracy: 49.00%
# Epoch 135: loss on final training batch: 1.0600
# training accuracy: 60.33% validation accuracy: 49.50%
# Epoch 136: loss on final training batch: 1.0920
# training accuracy: 62.14% validation accuracy: 53.50%
# Epoch 137: loss on final training batch: 0.9862
# training accuracy: 65.02% validation accuracy: 55.50%
# Epoch 138: loss on final training batch: 0.9434
# training accuracy: 66.77% validation accuracy: 55.00%
# Epoch 139: loss on final training batch: 0.8869
# training accuracy: 68.84% validation accuracy: 54.50%
# Epoch 140: loss on final training batch: 0.8814
# training accuracy: 70.53% validation accuracy: 56.00%
# Epoch 141: loss on final training batch: 0.7831
# training accuracy: 73.15% validation accuracy: 59.00%
# Epoch 142: loss on final training batch: 0.8224
# training accuracy: 73.65% validation accuracy: 59.00%
# Epoch 143: loss on final training batch: 0.7636
# training accuracy: 74.28% validation accuracy: 59.00%
# Epoch 144: loss on final training batch: 0.7059
# training accuracy: 76.22% validation accuracy: 60.00%
# Epoch 145: loss on final training batch: 0.7635
# training accuracy: 75.91% validation accuracy: 60.50%
# Epoch 146: loss on final training batch: 0.7015
# training accuracy: 76.53% validation accuracy: 58.00%
# Epoch 147: loss on final training batch: 0.7035
# training accuracy: 76.47% validation accuracy: 59.00%
# Epoch 148: loss on final training batch: 0.6509
# training accuracy: 76.66% validation accuracy: 58.50%
# Epoch 149: loss on final training batch: 0.7327
# training accuracy: 76.35% validation accuracy: 58.00%
# Epoch 150: loss on final training batch: 0.7719
# training accuracy: 74.59% validation accuracy: 59.00%
# Epoch 151: loss on final training batch: 0.6502
# training accuracy: 77.91% validation accuracy: 60.50%
# Epoch 152: loss on final training batch: 0.7236
# training accuracy: 74.16% validation accuracy: 60.50%
# Epoch 153: loss on final training batch: 1.1055
# training accuracy: 64.27% validation accuracy: 55.00%
# Epoch 154: loss on final training batch: 0.8980
# training accuracy: 69.65% validation accuracy: 56.00%
# Epoch 155: loss on final training batch: 0.8530
# training accuracy: 71.21% validation accuracy: 58.00%
# Epoch 156: loss on final training batch: 0.8170
# training accuracy: 71.21% validation accuracy: 60.50%
# Epoch 157: loss on final training batch: 0.8009
# training accuracy: 73.78% validation accuracy: 57.50%
# Epoch 158: loss on final training batch: 0.6967
# training accuracy: 75.59% validation accuracy: 62.00%
# Epoch 159: loss on final training batch: 0.6720
# training accuracy: 78.10% validation accuracy: 60.50%
# Epoch 160: loss on final training batch: 0.6973
# training accuracy: 78.16% validation accuracy: 60.00%
# Epoch 161: loss on final training batch: 0.6210
# training accuracy: 81.66% validation accuracy: 62.50%
# Epoch 162: loss on final training batch: 0.6086
# training accuracy: 81.98% validation accuracy: 62.50%
# Epoch 163: loss on final training batch: 0.5561
# training accuracy: 82.67% validation accuracy: 63.00%
# Epoch 164: loss on final training batch: 0.5829
# training accuracy: 82.98% validation accuracy: 61.50%
# Epoch 165: loss on final training batch: 0.5591
# training accuracy: 83.54% validation accuracy: 62.50%
# Epoch 166: loss on final training batch: 0.5215
# training accuracy: 83.98% validation accuracy: 64.50%
# Epoch 167: loss on final training batch: 0.4890
# training accuracy: 84.73% validation accuracy: 64.00%
# Epoch 168: loss on final training batch: 0.5396
# training accuracy: 83.54% validation accuracy: 62.00%
# Epoch 169: loss on final training batch: 0.5206
# training accuracy: 83.79% validation accuracy: 62.00%
# Epoch 170: loss on final training batch: 0.5488
# training accuracy: 82.54% validation accuracy: 61.50%
# Epoch 171: loss on final training batch: 0.4964
# training accuracy: 83.17% validation accuracy: 63.00%
# Epoch 172: loss on final training batch: 0.4674
# training accuracy: 84.48% validation accuracy: 66.00%
# Epoch 173: loss on final training batch: 0.4555
# training accuracy: 85.42% validation accuracy: 61.50%
# Epoch 174: loss on final training batch: 0.4117
# training accuracy: 85.86% validation accuracy: 64.00%
# Epoch 175: loss on final training batch: 0.4647
# training accuracy: 85.73% validation accuracy: 64.50%
# Epoch 176: loss on final training batch: 0.5388
# training accuracy: 83.98% validation accuracy: 62.50%
# Epoch 177: loss on final training batch: 0.5388
# training accuracy: 83.92% validation accuracy: 65.00%
# Epoch 178: loss on final training batch: 0.4882
# training accuracy: 85.11% validation accuracy: 62.50%
# Epoch 179: loss on final training batch: 0.4228
# training accuracy: 87.30% validation accuracy: 64.50%
# Epoch 180: loss on final training batch: 0.3803
# training accuracy: 88.80% validation accuracy: 64.00%
# Epoch 181: loss on final training batch: 0.3476
# training accuracy: 87.86% validation accuracy: 66.00%
# Epoch 182: loss on final training batch: 0.3726
# training accuracy: 88.11% validation accuracy: 64.50%
# Epoch 183: loss on final training batch: 0.3798
# training accuracy: 86.92% validation accuracy: 63.50%
# Epoch 184: loss on final training batch: 0.4182
# training accuracy: 85.61% validation accuracy: 61.50%
# Epoch 185: loss on final training batch: 0.4022
# training accuracy: 87.11% validation accuracy: 62.50%
# Epoch 186: loss on final training batch: 0.4370
# training accuracy: 85.73% validation accuracy: 64.00%
# Epoch 187: loss on final training batch: 0.4695
# training accuracy: 87.05% validation accuracy: 65.00%
# Epoch 188: loss on final training batch: 0.4669
# training accuracy: 85.04% validation accuracy: 61.50%
# Epoch 189: loss on final training batch: 0.4360
# training accuracy: 87.30% validation accuracy: 63.50%
# Epoch 190: loss on final training batch: 0.6852
# training accuracy: 78.35% validation accuracy: 60.00%
# Epoch 191: loss on final training batch: 0.6907
# training accuracy: 79.10% validation accuracy: 60.00%
# Epoch 192: loss on final training batch: 0.7834
# training accuracy: 75.59% validation accuracy: 57.50%
# Epoch 193: loss on final training batch: 0.7989
# training accuracy: 74.84% validation accuracy: 56.50%
# Epoch 194: loss on final training batch: 0.6392
# training accuracy: 79.47% validation accuracy: 61.50%
# Epoch 195: loss on final training batch: 0.6113
# training accuracy: 82.04% validation accuracy: 61.00%
# Epoch 196: loss on final training batch: 0.5444
# training accuracy: 83.60% validation accuracy: 61.50%
# Epoch 197: loss on final training batch: 0.4645
# training accuracy: 86.36% validation accuracy: 66.00%
# Epoch 198: loss on final training batch: 0.4259
# training accuracy: 86.98% validation accuracy: 65.50%
# Epoch 199: loss on final training batch: 0.4246
# training accuracy: 87.92% validation accuracy: 66.50%

# %% [markdown]
# ## Plot
#
# plot_numerical_arrays: plot multiple arrays with the same length
#
# parameters:
# - num_arrays: numerical arrays with the same length
# - labels: labels of each array(with the same order of num_arrays)
# - xlabel
# - ylabel
# - title

# %%
plot_numerical_arrays([training_loss_array, validation_loss_array], ['training loss', 'validation loss'], 
                      xlabel='batches', ylabel='loss', title='train and validation losses for ' + model_name)

# %%
plot_numerical_arrays([training_accuracy_array, validation_accuracy_array], ['training accuracy', 'validation accuracy'], 
                      xlabel='batches', ylabel='accuracy', title='train and validation accuracies for ' + model_name)
